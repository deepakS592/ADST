# %%
import pandas as pd

# %%
data={
    'Age':[20,25,30,35,40]
}
data=pd.DataFrame(data)

# %%
print(data)
# Out:
#    Age
# 0   20
# 1   25
# 2   30
# 3   35
# 4   40

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scale=MinMaxScaler()
data['NormalData']=scale.fit_transform(data[['Age']])

# %%
data
# Out:
#    Age  NormalData
# 0   20        0.00
# 1   25        0.25
# 2   30        0.50
# 3   35        0.75
# 4   40        1.00
