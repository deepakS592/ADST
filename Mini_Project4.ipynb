# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\surfce\Downloads\trends.csv")

# %%
data.head()
# Out:
#   location  year         category  rank  query
# 0   Global  2001  Consumer Brands     1  Nokia
# 1   Global  2001  Consumer Brands     2   Sony
# 2   Global  2001  Consumer Brands     3    BMW
# 3   Global  2001  Consumer Brands     4   Palm
# 4   Global  2001  Consumer Brands     5  Adobe

# %%
data.tail()
# Out:
#       location  year category  rank                query
# 26950  Vietnam  2020   Là Gì?     1   Virus Corona là gì
# 26951  Vietnam  2020   Là Gì?     2  Miễn thị thực là gì
# 26952  Vietnam  2020   Là Gì?     3    Đầu cắt moi là gì
# 26953  Vietnam  2020   Là Gì?     4  Bệnh bạch hầu là gì
# 26954  Vietnam  2020   Là Gì?     5       Đông Lào là gì

# %%
data.info
# Out:
# <bound method DataFrame.info of       location  year         category  rank                query
# 0       Global  2001  Consumer Brands     1                Nokia
# 1       Global  2001  Consumer Brands     2                 Sony
# 2       Global  2001  Consumer Brands     3                  BMW
# 3       Global  2001  Consumer Brands     4                 Palm
# 4       Global  2001  Consumer Brands     5                Adobe
# ...        ...   ...              ...   ...                  ...
# 26950  Vietnam  2020           Là Gì?     1   Virus Corona là gì
# 26951  Vietnam  2020           Là Gì?     2  Miễn thị thực là gì
# 26952  Vietnam  2020           Là Gì?     3    Đầu cắt moi là gì
# 26953  Vietnam  2020           Là Gì?     4  Bệnh bạch hầu là gì
# 26954  Vietnam  2020           Là Gì?     5       Đông Lào là gì
#
# [26955 rows x 5 columns]>

# %%
data.describe()
# Out:
#                year         rank
# count  26955.000000  26955.00000
# mean    2015.243369      3.00000
# std        3.564683      1.41424
# min     2001.000000      1.00000
# 25%     2013.000000      2.00000
# 50%     2016.000000      3.00000
# 75%     2018.000000      4.00000
# max     2020.000000      5.00000

# %%
data.shape
# Out:
# (26955, 5)

# %%
data.columns
# Out:
# Index(['location', 'year', 'category', 'rank', 'query'], dtype='str')

# %%
data.dtypes
# Out:
# location      str
# year        int64
# category      str
# rank        int64
# query         str
# dtype: object

# %%
data.isnull().sum()
# Out:
# location    0
# year        0
# category    0
# rank        0
# query       0
# dtype: int64

# %%
int(data.duplicated().sum())
# Out:
# 10

# %%
data.drop_duplicates(inplace=True)

# %%
data.nunique()
# Out:
# location       83
# year           20
# category     2450
# rank            5
# query       18431
# dtype: int64

# %%
column_name='rank'

# %%
Q1=data['rank'].quantile(0.25)

# %%
Q3=data['rank'].quantile(0.75)

# %%
IQR=Q3-Q1

# %%
print(Q1)
# Out:
# 2.0

# %%
print(Q3)
# Out:
# 4.0

# %%
print(IQR)
# Out:
# 2.0

# %%
LF=Q1-1.5*IQR

# %%
UF=Q3+1.5*IQR

# %%
print(LF)
# Out:
# -1.0

# %%
print(UF)
# Out:
# 7.0

# %%
outliers=data[(data['rank']<LF) | (data['rank']>UF)]

# %%
print(f"Number of outliers: {len(outliers)}")
# Out:
# Number of outliers: 0

# %%
display(outliers)
# Out:
# Empty DataFrame
# Columns: [location, year, category, rank, query]
# Index: []

# %%
column_name1='year'

# %%
Q1=data['year'].quantile(0.25)

# %%
Q3=data['year'].quantile(0.75)

# %%
IQR=Q3-Q1

# %%
print(Q1)
print(Q3)
print(IQR)
# Out:
# 2013.0
# 2018.0
# 5.0

# %%
LF=Q1-1.5*IQR

# %%
UF=Q3+1.5*IQR

# %%
print(LF)
# Out:
# 2005.5

# %%
print(UF)
# Out:
# 2025.5

# %%
outliers=data[(data['year']<LF) | (data['year']>UF)]

# %%
print(f"Number of outliers: {len(outliers)}")
# Out:
# Number of outliers: 480

# %%
display(outliers)
# Out:
#     location  year         category  rank              query
# 0     Global  2001  Consumer Brands     1              Nokia
# 1     Global  2001  Consumer Brands     2               Sony
# 2     Global  2001  Consumer Brands     3                BMW
# 3     Global  2001  Consumer Brands     4               Palm
# 4     Global  2001  Consumer Brands     5              Adobe
# ..       ...   ...              ...   ...                ...
# 475   Global  2005    Most Searched     1      Janet Jackson
# 476   Global  2005    Most Searched     2  Hurricane Katrina
# 477   Global  2005    Most Searched     3            Tsunami
# 478   Global  2005    Most Searched     4           Xbox 360
# 479   Global  2005    Most Searched     5          Brad Pitt
#
# [480 rows x 5 columns]
